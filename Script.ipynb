# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
companies = pd.read_csv('datasets_491494_914411_1000_Companies.csv')
companies.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
companies.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count    1000.000000     1000.000000      1000.000000    1000.000000
# mean    81668.927200   122963.897612    226205.058419  119546.164656
# std     46537.567891    12613.927535     91578.393542   42888.633848
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     43084.500000   116640.684850    150969.584600   85943.198543
# 50%     79936.000000   122421.612150    224517.887350  117641.466300
# 75%    124565.500000   129139.118000    308189.808525  155577.107425
# max    165349.200000   321652.140000    471784.100000  476485.430000

# %%
sns.lmplot(x='R&D Spend',y='Profit',data=companies,height=6)

# %%
sns.lmplot(x='Administration',y='Profit',data=companies,height=6)

# %%
sns.lmplot(x='Marketing Spend',y='Profit',data=companies,height=6)

# %%
sns.pairplot(companies)

# %%
#y = companies['Profit']
#X = companies[['R&D Spend','Administration','Marketing Spend']]
y = pd.DataFrame(companies['Profit'])
X = pd.DataFrame(companies[['R&D Spend','Administration','Marketing Spend']])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('The coefficients are:\n',lm.coef_)
# Out:
# The coefficients are:
#  [[0.64835349 0.86729695 0.04598628]]

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('y_test')
plt.ylabel('y_predicted')
# Out:
# Text(0, 0.5, 'y_predicted')

# %%
lm.coef_
# Out:
# array([[0.64835349, 0.86729695, 0.04598628]])
